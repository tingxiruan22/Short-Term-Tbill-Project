# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("3Mtbill_2017.csv")
df
# Out:
#             DATE DGS3MO
# 0     2017-11-22   1.29
# 1     2017-11-23      .
# 2     2017-11-24   1.29
# 3     2017-11-27   1.27
# 4     2017-11-28   1.30
# ...          ...    ...
# 1561  2023-11-16   5.51
# 1562  2023-11-17   5.50
# 1563  2023-11-20   5.54
# 1564  2023-11-21   5.53
# 1565  2023-11-22   5.54
#
# [1566 rows x 2 columns]

# %%
plt.plot(df['DATE'], df['int'])
plt.show()

# %%
df['DATE'] = pd.to_datetime(df['DATE'])

# Replace dots with NaN and convert to numeric
df['DGS3MO'].replace('.', None, inplace=True)
df['DGS3MO'] = pd.to_numeric(df['DGS3MO'], errors='coerce')

# Forward fill NaN values
df['DGS3MO'] = df['DGS3MO'].ffill()

df.rename(columns={'DGS3MO': 'int'}, inplace=True)

# %%
df['pct_change'] = df['int'].pct_change() 
df
# Out:
#            DATE   int  pct_change
# 0    2017-11-22  1.29         NaN
# 1    2017-11-23  1.29    0.000000
# 2    2017-11-24  1.29    0.000000
# 3    2017-11-27  1.27   -0.015504
# 4    2017-11-28  1.30    0.023622
# ...         ...   ...         ...
# 1561 2023-11-16  5.51   -0.003617
# 1562 2023-11-17  5.50   -0.001815
# 1563 2023-11-20  5.54    0.007273
# 1564 2023-11-21  5.53   -0.001805
# 1565 2023-11-22  5.54    0.001808
#
# [1566 rows x 3 columns]

# %%
plt.plot(df['DATE'], df['pct_change'], linewidth=0.5)
plt.show()

# %%
plt.plot(df['DATE'], df['int'])
plt.show()
